# %%
python -c "import wget; wget.download(""https://cdn.kernel.org/pub/linux/kernel/v4.x/linux-4.17.2.tar.xz"", ""C:\\Users\\TestName.TestExtension"")"
# Out:
#   Cell In[4], line 1
#     python -c "import wget; wget.download(""https://cdn.kernel.org/pub/linux/kernel/v4.x/linux-4.17.2.tar.xz"", ""C:\\Users\\TestName.TestExtension"")"
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as ps
ds=ps.read_csv("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv")
ds.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
ds.columns = ds.columns.str.lower().str.replace(' ', '_')
ds
# Out:
#                                                  laptop       status   brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#            model                cpu  ram  storage storage_type       gpu  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       screen touch  final_price
# 0       15.6    No      1009.00
# 1       15.6    No       299.00
# 2       15.6    No       789.00
# 3       15.6    No      1199.00
# 4       15.6    No       669.01
# ...      ...   ...          ...
# 2155    17.3    No      2699.99
# 2156    17.3    No      2899.99
# 2157    17.3    No      3399.99
# 2158    13.4   Yes      1899.99
# 2159    13.4   Yes      1699.99
#
# [2160 rows x 12 columns]

# %%
ds.columns[ds.isnull().any()]
# Out:
# Index(['storage_type', 'gpu', 'screen'], dtype='object')

# %%
ds.head()
# Out:
#                                               laptop status   brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         model            cpu  ram  storage storage_type       gpu  screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   touch  final_price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
ds.columns[ds.isnull().any()]
# Out:
# Index(['storage_type', 'gpu', 'screen'], dtype='object')

# %%
filtered_df = ds

# %%
shuffled_df = filtered_df.sample(frac=1, random_state=42).reset_index(drop=True)
shuffled_df
# Out:
#                                                  laptop       status  \
# 0     MSI Modern 15 A11SBU-620XES Intel Core i7-1165...  Refurbished
# 1     Thomson Neo White Intel Celeron N4020/4GB/64GB...          New
# 2     MSI Modern 14 B11SB-420XES Intel Core i7-1165G...  Refurbished
# 3     ASUS ZenBook 13 OLED UX325EA Intel Evo Core i7...          New
# 4     Acer Predator Triton 500 SE PT516-51s-75K6 Int...          New
# ...                                                 ...          ...
# 2155  Microsoft Surface Laptop 5 Platino Intel Evo C...          New
# 2156  Acer Extensa 15 EX215-52-59MA Intel Core i5-10...          New
# 2157  Apple MacBook Air Intel Core i5/8GB/256GB SSD/...  Refurbished
# 2158  Acer TravelMate P2 Intel Core i5-1135G7/8GB/51...          New
# 2159  MSI Creator M16 B13VE-681ES Intel Core i7-1370...          New
#
#           brand           model                cpu  ram  storage storage_type  \
# 0           MSI          Modern      Intel Core i7   32     1000          SSD
# 1       Thomson             Neo      Intel Celeron    4       64         eMMC
# 2           MSI          Modern      Intel Core i7   32     1000          SSD
# 3          Asus         ZenBook  Intel Evo Core i7   16      512          SSD
# 4          Acer        Predator      Intel Core i7   32     1000          SSD
# ...         ...             ...                ...  ...      ...          ...
# 2155  Microsoft  Surface Laptop  Intel Evo Core i7    8      512          SSD
# 2156       Acer         Extensa      Intel Core i5    8      256          SSD
# 2157      Apple     MacBook Air      Intel Core i5    8      256          SSD
# 2158       Acer      TravelMate      Intel Core i5    8      512          SSD
# 2159        MSI         Creator      Intel Core i7   32     1000          SSD
#
#            gpu  screen touch  final_price
# 0       MX 450    15.6    No      1123.29
# 1          NaN    14.1    No       201.05
# 2       MX 450    14.0    No       997.74
# 3          NaN    13.3    No      1016.00
# 4     RTX 3080    16.0    No      2739.00
# ...        ...     ...   ...          ...
# 2155       NaN    15.0   Yes      1838.29
# 2156       NaN    15.6    No       531.80
# 2157       NaN    13.3    No       765.33
# 2158       NaN    14.0    No       803.61
# 2159  RTX 4050    16.0    No      2102.18
#
# [2160 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
train_val, test = train_test_split(shuffled_df, test_size=0.2, random_state=42)  # 80% train_val, 20% test
train_val, test
# Out:
# (                                                 laptop       status   brand  \
#  1776  Acer Nitro 5 AN515-58-7365 Intel Core i7-12700...  Refurbished    Acer
#  381   HP OMEN 17-CB1005NS Intel Core i7-10750H/32GB/...  Refurbished      HP
#  1242  MSI Creator M16 B13UDX-687XES Intel Core i7-13...          New     MSI
#  1805  MSI Creator Pro M16 B13VI-1023ES Intel Core i7...          New     MSI
#  1865  ASUS ExpertBook B1 B1402CBA-EB0861W Intel Core...          New    Asus
#  ...                                                 ...          ...     ...
#  1638  ASUS TUF Gaming A15 2013 TUF507NU-LP036 AMD Ry...          New    Asus
#  1095  HP EliteBook 650 G9 Intel Core i7-1255U/8GB/51...  Refurbished      HP
#  1130  MSI Modern 15 B12M-043XES Intel Core i7-1255U/...  Refurbished     MSI
#  1294  Lenovo Yoga 7 14ITL5 Intel Evo Core i7-1165G7/...          New  Lenovo
#  860   ASUS VivoBook 15 F1502ZA-EJ1112W Intel Core i7...          New    Asus
#
#             model                cpu  ram  storage storage_type        gpu  \
#  1776       Nitro      Intel Core i7   16      512          SSD   RTX 3050
#  381         Omen      Intel Core i7   32     1000          SSD   RTX 2080
#  1242     Creator      Intel Core i7   16     1000          SSD   RTX 3050
#  1805     Creator      Intel Core i7   16     1000          SSD  RTX A1000
#  1865  ExpertBook      Intel Core i5   16      512          SSD        NaN
#  ...          ...                ...  ...      ...          ...        ...
#  1638         TUF        AMD Ryzen 7   16      512          SSD   RTX 4050
#  1095   EliteBook      Intel Core i7    8      512          SSD        NaN
#  1130      Modern      Intel Core i7   16     1000          SSD        NaN
#  1294        Yoga  Intel Evo Core i7   16      512          SSD        NaN
#  860     VivoBook      Intel Core i7   16      512          SSD        NaN
#
#        screen touch  final_price
#  1776    15.6    No      1299.00
#  381     17.3    No      1297.04
#  1242    16.0    No      1599.00
#  1805    16.0    No      1980.20
#  1865    14.0    No       800.00
#  ...      ...   ...          ...
#  1638    15.6    No      1175.01
#  1095    15.6    No      1654.05
#  1130    15.6    No      1049.00
#  1294    14.0   Yes      1671.00
#  860     15.6    No       755.00
#
#  [1728 rows x 12 columns],
#                                                   laptop       status  \
#  2079  Acer ConceptD 3 Pro CN316-73P-77Y4 Intel Core ...          New
#  668   Acer ConceptD 3 CN315-72G Intel Core i5-10300H...          New
#  2073  ASUS VivoBook Flip 14 TP401MA-EC448W Intel Cel...          New
#  1113  Acer Aspire 3 A317-53-53U0 Intel Core i5-1135G...          New
#  788   Razer Blade 17 QHD 240Hz Intel Core i9-12900H/...          New
#  ...                                                 ...          ...
#  438   Microsoft Surface Pro 7 Intel Core i7-1065G7/1...  Refurbished
#  900   Lenovo ThinkPad E15 Gen 4 Intel Core i5-1235U/...          New
#  1613  HP EliteBook 860 G9 Intel Core i5-1235U/16GB/5...          New
#  20    HP ProBook 450 G9 Intel Core i7-1255U/16GB/1TB...          New
#  785   HP 250 G9 Intel Core i3-1215U/8GB/512GB SSD/15.6"          New
#
#            brand        model            cpu  ram  storage storage_type  \
#  2079       Acer     ConceptD  Intel Core i7   16     1000          SSD
#  668        Acer     ConceptD  Intel Core i5    8      512          SSD
#  2073       Asus     VivoBook  Intel Celeron    4      256          SSD
#  1113       Acer       Aspire  Intel Core i5    8      512          SSD
#  788       Razer        Blade  Intel Core i9   16     1000          SSD
#  ...         ...          ...            ...  ...      ...          ...
#  438   Microsoft  Surface Pro  Intel Core i7   16      256          SSD
#  900      Lenovo     ThinkPad  Intel Core i5    8      256          SSD
#  1613         HP    EliteBook  Intel Core i5   16      512          SSD
#  20           HP      ProBook  Intel Core i7   16     1000          SSD
#  785          HP          250  Intel Core i3    8      512          SSD
#
#             gpu  screen touch  final_price
#  2079    T 1200    16.0    No      1471.61
#  668   GTX 1650    15.6    No      1349.00
#  2073       NaN    14.0   Yes       398.01
#  1113       NaN    17.3    No       729.00
#  788   RTX 3070    17.3    No      3899.99
#  ...        ...     ...   ...          ...
#  438        NaN    12.3    No      1094.03
#  900        NaN    15.6    No      1135.00
#  1613       NaN    16.0    No      1463.31
#  20         NaN    15.6    No      1312.00
#  785        NaN    15.6    No       398.10
#
#  [432 rows x 12 columns])

# %%
train, val = train_test_split(train_val, test_size=0.25, random_state=42)
train, val
# Out:
# (                                                 laptop       status    brand  \
#  1781  Thomson NEO Z3 Qualcomm Snapdragon 850/8GB/256...          New  Thomson
#  2024  HP 15S-EQ2130NS AMD Ryzen 5 5500U/8GB/512GB SS...          New       HP
#  2109  ASUS Chromebook CX1700CKA-BX0079 Intel Celeron...          New     Asus
#  33    ASUS E410MA-EK1356WS Intel Celeron N4020/4GB/6...          New     Asus
#  1720  ASUS ExpertBook B6 Flip B6602FC2-MH0248X Intel...          New     Asus
#  ...                                                 ...          ...      ...
#  216   ASUS Vivobook K513EP-51BM3SB2 Intel Core i5-11...          New     Asus
#  1976  MSI Pulse GL76 11UEK-055XES Intel Core i7-1180...  Refurbished      MSI
#  183   Dell Vostro 3520 Intel Core i7-1255U/16 GB/512...          New     Dell
#  1696  Lenovo IdeaPad 3 15ITL6 Intel Core i3-1115G4/8...          New   Lenovo
#  61    ASUS ZenBook 14 OLED UM3402YA-KM512WS AMD Ryze...          New     Asus
#
#             model                    cpu  ram  storage storage_type        gpu  \
#  1781          Go  Qualcomm Snapdragon 8    8      256          NaN        NaN
#  2024         15S            AMD Ryzen 5    8      512          SSD        NaN
#  2109  Chromebook          Intel Celeron    8       64         eMMC        NaN
#  33          E410          Intel Celeron    4       64         eMMC        NaN
#  1720  ExpertBook          Intel Core i7   16      512          SSD  RTX A2000
#  ...          ...                    ...  ...      ...          ...        ...
#  216     VivoBook          Intel Core i5    8      512          SSD     MX 330
#  1976       Pulse          Intel Core i7   16     1000          SSD   RTX 3060
#  183       Vostro          Intel Core i7   16      512          SSD        NaN
#  1696     IdeaPad          Intel Core i3    8      512          SSD        NaN
#  61       ZenBook            AMD Ryzen 7   16      512          SSD        NaN
#
#        screen touch  final_price
#  1781    13.0    No       436.56
#  2024    15.6    No       652.92
#  2109    17.3    No       429.00
#  33      14.0    No       349.00
#  1720    16.0   Yes      2499.00
#  ...      ...   ...          ...
#  216     15.6    No       867.00
#  1976    17.3    No      1334.69
#  183     15.6    No       997.79
#  1696    15.6    No       547.91
#  61      14.0    No      1149.00
#
#  [1296 rows x 12 columns],
#                                                   laptop       status  \
#  982   Acer Extensa 15 EX215-22-R3V0 AMD Ryzen 5 3500...          New
#  1015  HP ProBook 440 G9 Intel Core i7-1255U/16GB/1TB...          New
#  10    Lenovo V15 G2 ITL Intel Core i7-1165G7/16GB/51...          New
#  2123  MSI GP66 Leopard 10UE-226XES Intel Core i7-107...  Refurbished
#  116   Microsoft Surface Laptop Go 2 Intel Core i5-11...          New
#  ...                                                 ...          ...
#  1910  HP 250 G8 Intel Core i5-1135G7/8 GB/512 GB SSD...          New
#  1938  Lenovo Legion 5 15ITH6H Intel Core i7-11800H/3...  Refurbished
#  491   Lenovo IdeaPad 5 Pro 14ITL6 Intel Core i5-1135...          New
#  1458  MSI GL65 Leopard 10SFSK-280XES Intel Core i7-1...  Refurbished
#  341   HP Pavilion Gaming 16-A0029NS Intel Core i7-10...  Refurbished
#
#            brand           model            cpu  ram  storage storage_type  \
#  982        Acer         Extensa    AMD Ryzen 5    8      256          SSD
#  1015         HP         ProBook  Intel Core i7   16     1000          SSD
#  10       Lenovo             V15  Intel Core i7   16      512          SSD
#  2123        MSI         Leopard  Intel Core i7   16     1000          SSD
#  116   Microsoft  Surface Laptop  Intel Core i5    8      256          SSD
#  ...         ...             ...            ...  ...      ...          ...
#  1910         HP             250  Intel Core i5    8      512          SSD
#  1938     Lenovo          Legion  Intel Core i7   32     1000          SSD
#  491      Lenovo         IdeaPad  Intel Core i5    8      512          SSD
#  1458        MSI         Leopard  Intel Core i7   16     1000          SSD
#  341          HP        Pavilion  Intel Core i7   16      512          SSD
#
#             gpu  screen touch  final_price
#  982        NaN    15.6    No       439.00
#  1015       NaN    14.0    No      1214.49
#  10         NaN    15.6    No       969.00
#  2123  RTX 3060    15.6    No      1086.64
#  116        NaN    12.4   Yes       869.00
#  ...        ...     ...   ...          ...
#  1910       NaN    15.6    No       549.00
#  1938  RTX 3070    15.6    No      1799.00
#  491        NaN    14.0    No      1274.90
#  1458  RTX 2070    15.6    No       901.09
#  341   RTX 2060    16.1    No       711.94
#
#  [432 rows x 12 columns])

# %%
print("Train set size:", train.shape)
print("Validation set size:", val.shape)
print("Test set size:", test.shape)
# Out:
# Train set size: (1296, 12)
# Validation set size: (432, 12)
# Test set size: (432, 12)
